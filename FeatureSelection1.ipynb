# %%
import pandas as pd

# %%
data = pd.read_csv('E:\\DataScience\\Data\\train.csv')

# %%
data=data[:15000]

# %%
data.describe()
# Out:
#                  ID           var3         var15  imp_ent_var16_ult1  \
# count  15000.000000   15000.000000  15000.000000        15000.000000
# mean   15050.804667   -1530.582800     33.227933           85.032080
# std     8697.547004   39129.142108     12.857333         1957.637064
# min        1.000000 -999999.000000      5.000000            0.000000
# 25%     7533.750000       2.000000     23.000000            0.000000
# 50%    15026.500000       2.000000     28.000000            0.000000
# 75%    22551.500000       2.000000     40.000000            0.000000
# max    30168.000000     235.000000    102.000000       210000.000000
#
#        imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# count             15000.000000             15000.000000
# mean                 74.257806               125.182164
# std                 351.951292               573.789577
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# ...

# %%
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split

# %%
feature = data.drop(columns='TARGET')

# %%
target = data.TARGET
target.value_counts()
# Out:
# 0    14395
# 1      605
# Name: TARGET, dtype: int64

# %%
x_train,y_train,x_test,y_test = train_test_split(feature,target)

# %%
vt = VarianceThreshold(threshold=0) #removing constant features

# %%
vt.fit_transform(x_train)
# Out:
# array([[1.55960000e+04, 2.00000000e+00, 2.60000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 1.49155650e+05],
#        [9.72000000e+03, 2.00000000e+00, 2.50000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 8.40287400e+04],
#        [8.95900000e+03, 2.00000000e+00, 4.00000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 6.41253000e+04],
#        ...,
#        [1.33120000e+04, 2.00000000e+00, 2.30000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 1.17310979e+05],
#        [2.87900000e+04, 2.00000000e+00, 2.30000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 2.01984900e+05],
#        [8.12500000e+03, 2.00000000e+00, 2.60000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 8.45250000e+04]])

# %%
x_train.columns[vt.get_support()]
# Out:
# Index(['ID', 'var3', 'var15', 'imp_ent_var16_ult1', 'imp_op_var39_comer_ult1',
#        'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1',
#        'imp_op_var40_comer_ult3', 'imp_op_var40_efect_ult1',
#        'imp_op_var40_efect_ult3',
#        ...
#        'saldo_medio_var29_ult3', 'saldo_medio_var33_hace2',
#        'saldo_medio_var33_hace3', 'saldo_medio_var33_ult1',
#        'saldo_medio_var33_ult3', 'saldo_medio_var44_hace2',
#        'saldo_medio_var44_hace3', 'saldo_medio_var44_ult1',
#        'saldo_medio_var44_ult3', 'var38'],
#       dtype='object', length=292)

# %%
x_train[x_train.columns[vt.get_support()]]
# Out:
#           ID  var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# 7751   15596     2     26                 0.0                      0.0
# 4858    9720     2     25                 0.0                      0.0
# 4459    8959     2     40                 0.0                      0.0
# 14008  28126     2     19                 0.0                      0.0
# 4719    9439     5     57                 0.0                    300.0
# ...      ...   ...    ...                 ...                      ...
# 1599    3170     2     29                 0.0                      0.0
# 9841   19789     2     39              2400.0                     90.3
# 6630   13312     2     23                 0.0                      0.0
# 14317  28790     2     23                 0.0                      0.0
# 4053    8125     2     26                 0.0                      0.0
#
#        imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  \
# 7751                      0.00                      0.0
# ...

# %%
x_train = x_train[x_train.columns[vt.get_support()]]

# %%
x_train.shape
# Out:
# (11250, 292)

# %%
vt_q = VarianceThreshold(threshold=0.2)# removing quasi constant features
vt_q.fit_transform(x_train)
# Out:
# array([[1.55960000e+04, 2.00000000e+00, 2.60000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 1.49155650e+05],
#        [9.72000000e+03, 2.00000000e+00, 2.50000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 8.40287400e+04],
#        [8.95900000e+03, 2.00000000e+00, 4.00000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 6.41253000e+04],
#        ...,
#        [1.33120000e+04, 2.00000000e+00, 2.30000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 1.17310979e+05],
#        [2.87900000e+04, 2.00000000e+00, 2.30000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 2.01984900e+05],
#        [8.12500000e+03, 2.00000000e+00, 2.60000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 8.45250000e+04]])

# %%
x_train.columns[vt_q.get_support()]
# Out:
# Index(['ID', 'var3', 'var15', 'imp_ent_var16_ult1', 'imp_op_var39_comer_ult1',
#        'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1',
#        'imp_op_var40_comer_ult3', 'imp_op_var40_efect_ult1',
#        'imp_op_var40_efect_ult3',
#        ...
#        'saldo_medio_var29_ult3', 'saldo_medio_var33_hace2',
#        'saldo_medio_var33_hace3', 'saldo_medio_var33_ult1',
#        'saldo_medio_var33_ult3', 'saldo_medio_var44_hace2',
#        'saldo_medio_var44_hace3', 'saldo_medio_var44_ult1',
#        'saldo_medio_var44_ult3', 'var38'],
#       dtype='object', length=183)

# %%
x_train = x_train[x_train.columns[vt_q.get_support()]]

# %%
x_train.shape
# Out:
# (11250, 183)
